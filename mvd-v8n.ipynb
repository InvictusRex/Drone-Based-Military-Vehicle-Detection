# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
# ...

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.145 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6361.9/8062.4 GB disk)

# %%
import os
os.environ["WANDB_MODE"] = "disabled"

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/kaggle/input/military-vehicle-detection/Filtered_MVD/data.yaml epochs=100 patience=25 imgsz=1024 batch=64 augment=True cache=True half=True lr0=0.005 device=0,1 project=training_iteration_1 name=training_iteration_1
# Out:
# ...
# 100%|██████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 80.0MB/s]
# Ultralytics 8.3.145 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#                                                         CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/kaggle/working/training_iteration_1/training_iteration_1/weights/best.pt conf=0.45 source=/kaggle/input/military-vehicle-detection/Filtered_MVD/test/images save=True
# Out:
# Ultralytics 8.3.145 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/479 /kaggle/input/military-vehicle-detection/Filtered_MVD/test/images/00000407_jpg.rf.1c97d21b76a858830dd19c6e77e13614.jpg: 1024x1024 1 tank, 1 armored_vehicle, 13.4ms
# image 2/479 /kaggle/input/military-vehicle-detection/Filtered_MVD/test/images/00000411_jpg.rf.6849d344955271263d2c3782f3c4ad81.jpg: 1024x1024 1 tank, 13.3ms
# image 3/479 /kaggle/input/military-vehicle-detection/Filtered_MVD/test/images/05925_jpg.rf.a575b0544340030b5fbfe68efed379a2.jpg: 1024x1024 2 tanks, 13.3ms
# image 4/479 /kaggle/input/military-vehicle-detection/Filtered_MVD/test/images/111_jpg.rf.5ae0b8f5647fd613b37c7ff4f134e5ba.jpg: 1024x1024 1 tank, 13.3ms
# image 5/479 /kaggle/input/military-vehicle-detection/Filtered_MVD/test/images/119_jpg.rf.c8fb0916ffb180409a86c094dbfc4bdc.jpg: 1024x1024 1 tank, 2 armored_vehicles, 13.3ms
# ...

# %%
# !zip -r iteration_1_results.zip /kaggle/working/runs/detect/predict
# Out:
#   adding: kaggle/working/runs/detect/predict/ (stored 0%)
#   adding: kaggle/working/runs/detect/predict/t55_l5_jpg.rf.12b0f82fed4f1ae60923f769c9a92f18.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/predict/armored-personnel-carrier-btr-soviet-union-44179601_jpg.rf.748b138b38359abb8ea5b306be13a6e3.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/predict/IMG_2728_MP4-66_jpg.rf.6650df2957c1369c54e058fca8a5cea3.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/predict/sys_media_261_jpg.rf.3e0fa837d07256a97d77ab0789054306.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/predict/video_2022-10-13_12-56-52_mp4-287_jpg.rf.7ed73575b2cd960562642ca3e184908a.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/predict/pt_16_l2_jpg.rf.adae6f563c5135baa03a24ff1d20ad47.jpg (deflated 5%)
# ...

# %%
# !zip -r iteration_1_metrics.zip /kaggle/working/training_iteration_1/training_iteration_1
# Out:
#   adding: kaggle/working/training_iteration_1/training_iteration_1/ (stored 0%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/P_curve.png (deflated 8%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/results.csv (deflated 61%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/val_batch2_labels.jpg (deflated 1%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/val_batch1_labels.jpg (deflated 1%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/train_batch2.jpg (deflated 2%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/val_batch2_pred.jpg (deflated 2%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/confusion_matrix_normalized.png (deflated 21%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/labels_correlogram.jpg (deflated 33%)
# ...
